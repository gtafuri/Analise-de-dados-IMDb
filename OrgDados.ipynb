# %% [markdown]
# <a href="https://colab.research.google.com/github/gtafuri/Analise-de-dados-IMDb/blob/main/OrgDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importando dados

# %% [markdown]
# Visualizando dados

# %%
dados = pd.read_csv("/root/.cache/kagglehub/datasets/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows/versions/1/imdb_top_1000.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dados = pd.read_csv("/root/.cache/kagglehub/datasets/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows/versions/1/imdb_top_1000.csv")
#
# NameError: name 'pd' is not defined

# %%
dados.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
dados.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %%
dados.shape
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
dados.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %% [markdown]
# limpeza

# %%
#checando duplicatas
dados[dados.duplicated()] #não existem dados duplicados
# Out:
# Empty DataFrame
# Columns: [Poster_Link, Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Overview, Meta_score, Director, Star1, Star2, Star3, Star4, No_of_Votes, Gross]
# Index: []

# %% [markdown]
# Retirando colunas com valores nulos

# %%
dados.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %% [markdown]
# Limpando os nomes dos gêneros (tirar espaços)

# %%
dados['Genre'] = dados['Genre'].str.replace('\s*,\s*', ',', regex=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-368fbecfb785> in <cell line: 1>()
# ----> 1 dados['Genre'] = dados['Genre'].str.replace('\s*,\s*', ',', regex=True)
#
# NameError: name 'dados' is not defined

# %% [markdown]
# Visualizações

# %% [markdown]
# criando uma coluna "Decada"

# %%
dados['Released_Year'] = pd.to_numeric(dados['Released_Year'], errors='coerce')
dados['Decada'] = (dados['Released_Year'] // 10) * 10

# %% [markdown]
# Convertendo "Gross" de object para float

# %%
dados['Gross'] = dados['Gross'].str.replace(',', '', regex=True).astype(float)

# %%
dados["Gross"] = pd.to_numeric(dados['Gross'], errors = 'coerce')

# %% [markdown]
# Agrupando média de faturamento por década

# %%
media_faturamento = dados.groupby('Decada')['Gross'].mean().reset_index()
print(media_faturamento)
# Out:
#     Decada         Gross
# 0   1920.0  1.844978e+06
# 1   1930.0  1.840348e+07
# 2   1940.0  8.293462e+06
# 3   1950.0  1.417469e+07
# 4   1960.0  3.163478e+07
# 5   1970.0  5.287953e+07
# 6   1980.0  6.231487e+07
# 7   1990.0  6.123000e+07
# 8   2000.0  6.965808e+07
# 9   2010.0  1.037204e+08
# 10  2020.0           NaN

# %% [markdown]
# Gráfico de barras

# %%
#plt.bar(media_faturamento['Decada'], media_faturamento['Gross'], width = 8)
#plt.xlabel('Década')
#plt.ylabel('Faturamento')
#plt.title('Faturamento ao longo das décadas')
#plt.show()
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(media_faturamento['Decada'], media_faturamento['Gross'], width=8, color='teal', alpha=0.7)
ax.set_xlabel('Década')
ax.set_ylabel('Faturamento')
ax.set_title('Faturamento Médio por Década')
plt.grid(axis='y', alpha=0.6)
plt.show()

# %% [markdown]
# separando os gêneros e listando os faturamentos

# %%
faturamentoxgenero = dados.assign(Genre=dados['Genre'].str.split(',')).explode('Genre')
faturamentoxgenero =  faturamentoxgenero.dropna(subset = ['Gross'])
faturamentoxgenero = faturamentoxgenero.groupby('Genre')['Gross'].apply(list).reset_index(name='Faturamento')
print(faturamentoxgenero)
# Out:
#         Genre                                        Faturamento
# 0      Action  [534858444.0, 377845905.0, 292576195.0, 315544...
# 1   Adventure  [377845905.0, 292576195.0, 315544750.0, 342551...
# 2   Animation  [10055859.0, 422783777.0, 5017246.0, 190241310...
# 3   Biography  [96898818.0, 46836394.0, 13182281.0, 32572577....
# 4      Comedy  [53367844.0, 57598247.0, 13182281.0, 210609762...
# 5       Crime  [134966411.0, 534858444.0, 57300000.0, 4360000...
# 6       Drama  [28341469.0, 134966411.0, 534858444.0, 5730000...
# 7      Family  [10055859.0, 163245.0, 209726015.0, 1223869.0,...
# 8     Fantasy  [290475067.0, 136801374.0, 322740140.0, 501724...
# 9   Film-Noir  [5720000.0, 3969893.0, 449191.0, 2237659.0, 65...
# 10    History  [96898818.0, 75600000.0, 51973029.0, 5509040.0...
# 11     Horror  [32000000.0, 44017374.0, 78900000.0, 13782838....
# 12      Music  [13092000.0, 32572577.0, 1373943.0, 25000000.0...
# 13    Musical  [8819028.0, 10616104.0, 70147.0, 1787378.0, 41...
# 14    Mystery  [100125643.0, 53089891.0, 23341568.0, 32000000...
# 15    Romance  [330252182.0, 57598247.0, 11990401.0, 1024560....
# 16     Sci-Fi  [292576195.0, 171479930.0, 188020017.0, 530898...
# 17      Sport  [933933.0, 1626289.0, 13657115.0, 1113541.0, 2...
# 18   Thriller  [53367844.0, 130742922.0, 335451311.0, 1323843...
# 19        War  [216540909.0, 1024560.0, 83471511.0, 288475.0,...
# 20    Western  [6100000.0, 5321508.0, 162805434.0, 15000000.0...

# %% [markdown]
# Criando o bloxplot

# %%
fig, ax = plt.subplots()
ax.boxplot(faturamentoxgenero['Faturamento'], patch_artist=True, boxprops={'facecolor': 'bisque'})
ax.set_xticklabels(faturamentoxgenero['Genre'], rotation=90,)
ax.set_xlabel('Gênero')
ax.set_ylabel('Faturamento')

fig.show()

# %% [markdown]
# Boxplot notas IMDb vs notas MetaScore

# %%
plot = pd.DataFrame()
plot['IMDb'] = dados['IMDB_Rating'] *10
plot["MetaScore"] = dados["Meta_score"]

plot = pd.melt(plot, value_vars=["IMDb", "MetaScore"], var_name="Instituicao", value_name="Nota")
print(plot)

sns.boxplot(data=plot, x=0, y="Nota", hue="Instituicao")

plt.title("IMDb vs MetaScore")
plt.show()
# Out:
#      Instituicao  Nota
# 0           IMDb  93.0
# 1           IMDb  92.0
# 2           IMDb  90.0
# 3           IMDb  90.0
# 4           IMDb  90.0
# ...          ...   ...
# 1995   MetaScore  76.0
# 1996   MetaScore  84.0
# 1997   MetaScore  85.0
# 1998   MetaScore  78.0
# 1999   MetaScore  93.0
#
# [2000 rows x 2 columns]

# %% [markdown]
# Comparando as Notas IMDb e MetaScore por gênero

# %%
datam=pd.DataFrame()
datam['IMDb']= dados['IMDB_Rating'] * 10
datam['MetaScore'] = dados['Meta_score']
datam['Genre'] = dados ['Genre']

datam['Genre'] = datam["Genre"].str.split(',')
datam = datam.explode("Genre")
datam = datam.reset_index()

datam = datam.melt( id_vars = ["Genre"], value_vars=["IMDb","MetaScore"] ,value_name="Notas", var_name='Instituicao'  )

sns.boxplot(data= datam, y="Genre", x="Notas", hue="Instituicao")
plt.show()

# %% [markdown]
# Comparando a Evolução temporal das notas

# %%
import matplotlib.patches as mpatches

data = pd.DataFrame()
data['Released_Year'] = pd.to_numeric(dados['Released_Year'], 'coerce')

data['IMDB_Rating'] = dados['IMDB_Rating'] *10
data['Meta_score'] = dados['Meta_score']



sns.regplot(data=data, x = 'Released_Year', y = 'IMDB_Rating', order = 4, color = 'red', scatter_kws={'alpha':0.1})
sns.regplot(data=data, x = 'Released_Year', y = 'Meta_score', order = 4, color = 'blue', scatter_kws={'alpha':0.1})

plt.xlim(1920,2020)


plt.xlabel('Ano')
plt.ylabel('Nota')


blueLine = mpatches.Patch(color='blue', label='Meta Score')
redLine = mpatches.Patch(color='red', label='IMDB Rating')

plt.legend(handles=[blueLine, redLine])

plt.show()

# %% [markdown]
# Comparando a durção do filme com a nota MetaScore

# %%
data = pd.DataFrame()

data['Runtime'] = dados['Runtime'].str.split(' ').str[0].astype(int)
data['Meta_score'] = dados['Meta_score']

sns.regplot(data = data, x='Meta_score', y="Runtime",order = 2,scatter_kws={'alpha':0.1})
plt.ylim(0,250)
plt.ylabel('Duração')
plt.xlabel('Nota MetaScore')
plt.show()

# %% [markdown]
# Comparando a duração dos fimes a cada década

# %%
data = pd.DataFrame()

data['Released_Year'] = pd.to_numeric(dados['Released_Year'], 'coerce')

bins = [1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]
labels = ['1920', '1930', '1940', '1950', '1960','1970','1980', '1990',
          '2000', '2010']
data['Runtime'] = dados['Runtime'].str.split(' ').str[0].astype(int)

sns.regplot(data = data, x='Released_Year', y="Runtime",order = 4,scatter_kws={'alpha':0.1})
plt.ylim(0,250)
plt.show()

# %% [markdown]
# listando atores e suas frequências

# %%
frequencia = dados['Star1'].value_counts().reset_index(name='frequency')
temp1 = dados['Star2'].value_counts().reset_index(name='frequency')
temp2 = dados['Star3'].value_counts().reset_index(name='frequency')

frequencia = frequencia.rename(columns={"Star1": "n"})
temp1 = temp1.rename(columns={'Star2': 'n'})
temp2 = temp2.rename(columns={'Star3': 'n'})

frequencia = pd.concat([frequencia, temp1])
frequencia = pd.concat([frequencia, temp2])

frequencia = frequencia.groupby('n',as_index=False)['frequency'].sum()
frequencia = frequencia.sort_values(by='frequency', ascending=False)
print(frequencia)
# Out:
#                        n  frequency
# 1557      Robert De Niro         17
# 1830           Tom Hanks         14
# 25             Al Pacino         13
# 339       Clint Eastwood         12
# 1102   Leonardo DiCaprio         11
# ...                  ...        ...
# 272         Cecil Parker          1
# 963   Julianne Nicholson          1
# 273         Cecilia Roth          1
# 961      Julian Dennison          1
# 1981         Özge Özberk          1
#
# [1982 rows x 2 columns]

# %% [markdown]
# Utilizando a biblioteca wordcloud

# %%
d = {}
for n, Total in frequencia.values:
    d[n] = Total
wordcloud = WordCloud(background_color = 'white', # cor de fundo
                      width = 1000, # largura
                      height = 500, # altura
                      colormap = 'winter') # cor das palavras)
wordcloud.generate_from_frequencies(frequencies = d)

plt.figure(figsize = (15, 10))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Avaliando a porcentagem de cada gênero por década

# %%
data=pd.DataFrame()
data['Released_Year'] = pd.to_numeric(dados['Released_Year'], 'coerce')

bins = [1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]
labels = ['1920', '1930', '1940', '1950', '1960','1970','1980', '1990',
          '2000', '2010']

data['Released_Year'] = pd.cut(data['Released_Year'], bins = bins, labels = labels )

data['Genre'] = dados["Genre"].str.split(',')
data = data.explode("Genre")
data = data.reset_index()

plot = data.groupby(['Genre','Released_Year'], observed=False).size().unstack()

for row in plot:
    plot[row] = plot[row] / plot[row].sum()

plot = plot.transpose()
print(plot)
ax = sns.heatmap(data=plot, cmap="coolwarm")

plt.show()
# Out:
# Genre            Action  Adventure  Animation  Biography    Comedy     Crime  \
# Released_Year
# 1920           0.071429   0.071429   0.000000   0.035714  0.178571  0.000000
# 1930           0.024691   0.049383   0.012346   0.000000  0.160494  0.049383
# 1940           0.034884   0.034884   0.000000   0.000000  0.069767  0.104651
# 1950           0.020270   0.074324   0.000000   0.013514  0.060811  0.094595
# 1960           0.065359   0.065359   0.006536   0.052288  0.065359  0.052288
# 1970           0.065990   0.076142   0.015228   0.055838  0.091371  0.096447
# 1980           0.081818   0.095455   0.036364   0.040909  0.113636  0.072727
# 1990           0.069307   0.051980   0.047030   0.034653  0.103960  0.118812
# 2000           0.085308   0.082148   0.041074   0.045814  0.072670  0.082148
# 2010           0.095726   0.095726   0.041026   0.059829  0.100855  0.066667
#
# Genre             Drama    Family   Fantasy  Film-Noir  ...    Horror  \
# Released_Year                                           ...
# 1920           0.250000  0.035714  0.035714   0.000000  ...  0.035714
# 1930           0.197531  0.049383  0.024691   0.000000  ...  0.061728
# 1940           0.290698  0.023256  0.023256   0.151163  ...  0.000000
# 1950           0.344595  0.000000  0.006757   0.040541  ...  0.033784
# 1960           0.287582  0.026144  0.013072   0.000000  ...  0.039216
# 1970           0.263959  0.025381  0.025381   0.000000  ...  0.025381
# 1980           0.254545  0.031818  0.050000   0.000000  ...  0.004545
# 1990           0.292079  0.022277  0.027228   0.000000  ...  0.000000
# 2000           0.289100  0.028436  0.031596   0.000000  ...  0.006319
# 2010           0.292308  0.010256  0.017094   0.000000  ...  0.006838
#
# Genre             Music   Musical   Mystery   Romance    Sci-Fi     Sport  \
# Released_Year
# 1920           0.000000  0.000000  0.000000  0.107143  0.035714  0.000000
# 1930           0.012346  0.024691  0.061728  0.111111  0.049383  0.000000
# 1940           0.011628  0.000000  0.093023  0.069767  0.000000  0.000000
# 1950           0.006757  0.006757  0.047297  0.074324  0.013514  0.000000
# 1960           0.006536  0.013072  0.045752  0.039216  0.013072  0.006536
# 1970           0.015228  0.025381  0.025381  0.025381  0.030457  0.010152
# 1980           0.009091  0.000000  0.018182  0.022727  0.054545  0.000000
# 1990           0.014851  0.002475  0.037129  0.061881  0.019802  0.009901
# 2000           0.015798  0.006319  0.050553  0.044234  0.022117  0.009479
# 2010           0.017094  0.003419  0.025641  0.046154  0.030769  0.010256
#
# Genre          Thriller       War   Western
# Released_Year
# 1920           0.035714  0.035714  0.000000
# 1930           0.037037  0.037037  0.012346
# 1940           0.034884  0.046512  0.011628
# 1950           0.074324  0.027027  0.033784
# 1960           0.065359  0.058824  0.039216
# 1970           0.055838  0.030457  0.015228
# 1980           0.050000  0.027273  0.004545
# 1990           0.064356  0.007426  0.002475
# 2000           0.052133  0.014218  0.001580
# 2010           0.047863  0.010256  0.001709
#
# [10 rows x 21 columns]
